# %%
# importing dependencies

import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func

# %%
# establishing path and reading Imported Deforestation data into pandas
population_df = pd.read_csv(r"C:/Users/abrow/Desktop/EMERSON_BOOTCAMP/BOOTCAMP_AMB/Project_3/Project-3-Global-Warming/Data/Deforestation/owid-co2-data.csv")
population_df.head()
# Out:
#   iso_code      country  year    co2  consumption_co2  co2_growth_prct  \
# 0      AFG  Afghanistan  1949  0.015              NaN              NaN
# 1      AFG  Afghanistan  1950  0.084              NaN            475.0
# 2      AFG  Afghanistan  1951  0.092              NaN              8.7
# 3      AFG  Afghanistan  1952  0.092              NaN              0.0
# 4      AFG  Afghanistan  1953  0.106              NaN             16.0
#
#    co2_growth_abs  trade_co2  co2_per_capita  consumption_co2_per_capita  ...  \
# 0             NaN        NaN           0.002                         NaN  ...
# 1           0.070        NaN           0.011                         NaN  ...
# 2           0.007        NaN           0.012                         NaN  ...
# 3           0.000        NaN           0.012                         NaN  ...
# 4           0.015        NaN           0.013                         NaN  ...
#
#    ghg_per_capita  methane  methane_per_capita  nitrous_oxide  \
# ...

# %%
slimfast_pop_df = population_df[['iso_code', 'country', 'year', 'population']].copy()
slimfast_pop_df.head()
# Out:
#   iso_code      country  year  population
# 0      AFG  Afghanistan  1949   7624058.0
# 1      AFG  Afghanistan  1950   7752117.0
# 2      AFG  Afghanistan  1951   7840151.0
# 3      AFG  Afghanistan  1952   7935996.0
# 4      AFG  Afghanistan  1953   8039684.0

# %%
# Renaming the columns to be compatible with the other dataframes that it will be merged with
slimfast_pop_df.columns = ['Code', 'Entity' 'Year', 'Population']
slimfast_pop_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-4adc934f97a1> in <module>
#       1 # Renaming the columns to be compatible with the other dataframes that it will be merged with
# ----> 2 slimfast_pop_df.columns = ['Code', 'Entity' 'Year', 'Population']
#       3 slimfast_pop_df.head()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     668     def _set_axis(self, axis: int, labels: Index) -> None:
# ...
