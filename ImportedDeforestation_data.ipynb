# %%
# importing dependencies

import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func

# %%
# establishing path and reading Imported Deforestation data into pandas
imported_deforestation_df = pd.read_csv(r"C:/Users/abrow/Desktop/EMERSON_BOOTCAMP/BOOTCAMP_AMB/Project_3/Project-3-Global-Warming/Data/Deforestation/imported-deforestation.csv")
imported_deforestation_df.head()
# Out:
#         Entity Code  Year  imported_deforestation
# 0  Afghanistan  AFG  2005              358.921496
# 1  Afghanistan  AFG  2006              104.466376
# 2  Afghanistan  AFG  2007              157.641326
# 3  Afghanistan  AFG  2008              270.486447
# 4  Afghanistan  AFG  2009              583.772954

# %%
# Renaming the last column
imported_deforestation_df.columns = ['Entity', 'Code', 'Year', 'Imported Deforestation']
imported_deforestation_df.head()
# Out:
#         Entity Code  Year  Imported Deforestation
# 0  Afghanistan  AFG  2005              358.921496
# 1  Afghanistan  AFG  2006              104.466376
# 2  Afghanistan  AFG  2007              157.641326
# 3  Afghanistan  AFG  2008              270.486447
# 4  Afghanistan  AFG  2009              583.772954

# %%
# Checking data types to ensure compatability for ease of merging
imported_deforestation_df.dtypes
# Out:
# Entity                     object
# Code                       object
# Year                        int64
# Imported Deforestation    float64
# dtype: object

# %%
# Well I don't feel like counting how many different codes there are, so I'll make Pandas count the number of unique values for me...
# Creating a variable to hold the count
count = 0

# Creating an empty list to hold the counted values
counted = []

# loop for counting the unique values in in the code column
for i in range(0, len(imported_deforestation_df['Code'])):
    
    if imported_deforestation_df['Code'][i] not in counted:
        
        counted.append(imported_deforestation_df['Code'][i])
        
        count += 1
        
    print(count)
    
    print(counted)
# Out:
# 1
# ['AFG']
# 1
# ['AFG']
# 1
# ['AFG']
# 1
# ['AFG']
# 1
# ['AFG']
# 1
# ['AFG']
# 1
# ['AFG']
# 1
# ['AFG']
# 1
# ['AFG']
# 2
# ['AFG', 'ALB']
# 2
# ['AFG', 'ALB']
# 2
# ['AFG', 'ALB']
# 2
# ['AFG', 'ALB']
# 2
# ['AFG', 'ALB']
# 2
# ['AFG', 'ALB']
# 2
# ['AFG', 'ALB']
# 2
# ['AFG', 'ALB']
# 2
# ['AFG', 'ALB']
# 3
# ['AFG', 'ALB', 'DZA']
# 3
# ['AFG', 'ALB', 'DZA']
# 3
# ['AFG', 'ALB', 'DZA']
# 3
# ['AFG', 'ALB', 'DZA']
# 3
# ['AFG', 'ALB', 'DZA']
# 3
# ['AFG', 'ALB', 'DZA']
# 3
# ['AFG', 'ALB', 'DZA']
# 3
# ['AFG', 'ALB', 'DZA']
# 3
# ['AFG', 'ALB', 'DZA']
# 4
# ['AFG', 'ALB', 'DZA', 'AGO']
# 4
# ['AFG', 'ALB', 'DZA', 'AGO']
# 4
# ['AFG', 'ALB', 'DZA', 'AGO']
# 4
# ['AFG', 'ALB', 'DZA', 'AGO']
# 4
# ['AFG', 'ALB', 'DZA', 'AGO']
# 4
# ['AFG', 'ALB', 'DZA', 'AGO']
# 4
# ['AFG', 'ALB', 'DZA', 'AGO']
# 4
# ['AFG', 'ALB', 'DZA', 'AGO']
# 4
# ['AFG', 'ALB', 'DZA', 'AGO']
# 5
# ['AFG', 'ALB', 'DZA', 'AGO', 'ARG']
# 5
# ['AFG', 'ALB', 'DZA', 'AGO', 'ARG']
# 5
# ...

# %%
# Cool story bro...
# tl;dr... There are 190 unique codes...

# %%
# Creating path to read in Net Deforestation data

# %%
# Joining the two dataframes on
